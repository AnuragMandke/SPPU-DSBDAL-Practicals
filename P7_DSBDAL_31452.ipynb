# %% [markdown]
# Downloading the necessary packages

# %%
pip install nltk

# %%
import nltk
nltk.download('popular')
##downloading only the popular packages
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /home/te/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/te/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /home/te/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/te/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/te/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/te/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# ...

# %%
##or download all the packages from nltk
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# ...

# %% [markdown]
# Reading text file

# %%
# file=open('testdoc.txt','r')
file=open('dir_msg.txt','r')
text=file.read()
print(text)
# Out:
# ﻿Pune Institute of Computer Technology (PICT) was established in 1983 by a group of enterprising visionary professionals and has come a long way and marched ahead with quality education imbibed with professional and ethical values. Our mission is to be the most sought-after institute in Engineering education and research, that provides relevant knowledge, creates challenging opportunities, and inculcate values and social responsibilities. Pune Institute of Computer Technology has cut niche for itself to be one of the India’s leading institutions in higher Technical Education and Research of International repute. We celebrate the illustrious accomplishments of the past and take pride in our position as one of the top institutions of our country.
#
# ...

# %%
# file=open('testdoc.txt','r')
file2=open('pri_msg.txt','r')
text2=file2.read()
print(text2)
# Out:
# ﻿It gives me immense pleasure in welcoming you to SCTR’s Pune Institute of Computer Technology, a premier and a very reputed institute. Pune Institute of Computer Technology, popularly known as PICT, was established in 1983, by a group of great visionaries, Late Mr. Dr. N. Gopalkrishnan, Mr. N. Rama Krishnan and Managing Trustee Mr. Rajkumar Kothavale. The ingenious founder team and Secretary Mr. Swastik Sir continue to lead PICT in its journey of excellence.
#
# PICT, affiliated to Savitribai Phule Pune University is a pioneer in introducing Computer Engineering undergraduate program in Maharashtra state and it is recognized as the most sought-after institution, to educate young aspiring minds.
#
# ...

# %% [markdown]
# Tokenizing

# %%
tokens=nltk.word_tokenize(text)
tokens[0:20]
# Out:
# ['\ufeffPune',
#  'Institute',
#  'of',
#  'Computer',
#  'Technology',
#  '(',
#  'PICT',
#  ')',
#  'was',
#  'established',
#  'in',
#  '1983',
#  'by',
#  'a',
#  'group',
#  'of',
#  'enterprising',
#  'visionary',
#  'professionals',
#  'and']

# %%
tokens2=nltk.word_tokenize(text2)
tokens2[0:20]
# Out:
# ['\ufeffIt',
#  'gives',
#  'me',
#  'immense',
#  'pleasure',
#  'in',
#  'welcoming',
#  'you',
#  'to',
#  'SCTR',
#  '’',
#  's',
#  'Pune',
#  'Institute',
#  'of',
#  'Computer',
#  'Technology',
#  ',',
#  'a',
#  'premier']

# %% [markdown]
# POS Tagging

# %%
tagged=nltk.pos_tag(tokens)
tagged[0:20]
# Out:
# [('\ufeffPune', 'NNP'),
#  ('Institute', 'NNP'),
#  ('of', 'IN'),
#  ('Computer', 'NNP'),
#  ('Technology', 'NNP'),
#  ('(', '('),
#  ('PICT', 'NNP'),
#  (')', ')'),
#  ('was', 'VBD'),
#  ('established', 'VBN'),
#  ('in', 'IN'),
#  ('1983', 'CD'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('group', 'NN'),
#  ('of', 'IN'),
#  ('enterprising', 'VBG'),
#  ('visionary', 'JJ'),
#  ('professionals', 'NNS'),
#  ('and', 'CC')]

# %%
tagged2=nltk.pos_tag(tokens2)
tagged2[0:20]
# Out:
# [('\ufeffIt', 'NN'),
#  ('gives', 'VBZ'),
#  ('me', 'PRP'),
#  ('immense', 'JJ'),
#  ('pleasure', 'NN'),
#  ('in', 'IN'),
#  ('welcoming', 'VBG'),
#  ('you', 'PRP'),
#  ('to', 'TO'),
#  ('SCTR', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('Pune', 'NNP'),
#  ('Institute', 'NNP'),
#  ('of', 'IN'),
#  ('Computer', 'NNP'),
#  ('Technology', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('premier', 'NN')]

# %% [markdown]
# Removing stop words

# %%
from nltk.corpus import stopwords

# %%
stopWords=set(stopwords.words('english'))

# %%
import string

# %%
final_words=[w for w in tokens if w.lower() not in stopWords and w not in string.punctuation]

# %%
print('before: ',tokens[0:20])
print('after removing stop words: ',final_words[0:20])
# Out:
# before:  ['\ufeffPune', 'Institute', 'of', 'Computer', 'Technology', '(', 'PICT', ')', 'was', 'established', 'in', '1983', 'by', 'a', 'group', 'of', 'enterprising', 'visionary', 'professionals', 'and']
# after removing stop words:  ['\ufeffPune', 'Institute', 'Computer', 'Technology', 'PICT', 'established', '1983', 'group', 'enterprising', 'visionary', 'professionals', 'come', 'long', 'way', 'marched', 'ahead', 'quality', 'education', 'imbibed', 'professional']

# %%
final_words2=[w for w in tokens2 if w.lower() not in stopWords and w not in string.punctuation]

# %% [markdown]
# Stemming

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()

# %%
ind=0
for w in final_words:
    print(f"{w} -> {ps.stem(w)}")
    if ind==20:
        break
    ind+=1
# Out:
# ﻿Pune -> ﻿pune
# Institute -> institut
# Computer -> comput
# Technology -> technolog
# PICT -> pict
# established -> establish
# 1983 -> 1983
# group -> group
# enterprising -> enterpris
# visionary -> visionari
# professionals -> profession
# come -> come
# long -> long
# way -> way
# marched -> march
# ahead -> ahead
# quality -> qualiti
# education -> educ
# imbibed -> imbib
# professional -> profession
# ethical -> ethic

# %%
stemmed_tokens=[ps.stem(w) for w in final_words]

# %%
stemmed_tokens2=[ps.stem(w) for w in final_words2]

# %% [markdown]
# Lemmetization

# %%
from nltk.stem import WordNetLemmatizer
lm= WordNetLemmatizer()

# %%
ind=0
for w in final_words:
    print(f"{w} -> {lm.lemmatize(w)}")
    if ind==20:
        break
    ind+=1
# Out:
# ﻿Pune -> ﻿Pune
# Institute -> Institute
# Computer -> Computer
# Technology -> Technology
# PICT -> PICT
# established -> established
# 1983 -> 1983
# group -> group
# enterprising -> enterprising
# visionary -> visionary
# professionals -> professional
# come -> come
# long -> long
# way -> way
# marched -> marched
# ahead -> ahead
# quality -> quality
# education -> education
# imbibed -> imbibed
# professional -> professional
# ethical -> ethical

# %%
lemmatized_tokens=[lm.lemmatize(w) for w in final_words]

# %%
lemmatized_tokens2=[lm.lemmatize(w) for w in final_words2]

# %%
processed_texts=[]

# %%
processed_texts.append(" ".join(lemmatized_tokens))

# %%
processed_texts.append(" ".join(lemmatized_tokens2))

# %%
len(processed_texts)
# Out:
# 2

# %%
import pandas as pd

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer()

# %%
tfidf_matrix = tfidf.fit_transform(processed_texts)

tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf.get_feature_names_out())
print(tfidf_df)
# Out:
#          10       100        12        19      1983       1st      2015  \
# 0  0.099643  0.066429  0.033214  0.033214  0.023632  0.033214  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.031578  0.000000  0.044382
#
#         240       326      3500  ...      well  wellbeing  wireless      wish  \
# 0  0.033214  0.033214  0.033214  ...  0.000000   0.000000  0.033214  0.047265
# 1  0.000000  0.000000  0.000000  ...  0.044382   0.044382  0.000000  0.031578
#
#    wonderful      work  workshop     world      year     young
# 0   0.000000  0.047265  0.033214  0.023632  0.099643  0.023632
# 1   0.044382  0.031578  0.000000  0.126314  0.000000  0.126314
#
# [2 rows x 521 columns]

# %%
tfidf_matrix = tfidf.fit_transform(processed_texts)

tfidf_array = tfidf_matrix.toarray()
feature_names = tfidf.get_feature_names_out()



# Print TF-IDF Values
print("\nTF-IDF Representation for document 1:")
for word, score in zip(feature_names, tfidf_array[0]):
    print(f"{word}: {score:.4f}")
# Out:
# TF-IDF Representation for document 1:
# 10: 0.0996
# 100: 0.0664
# 12: 0.0332
# 19: 0.0332
# 1983: 0.0236
# 1st: 0.0332
# 2015: 0.0000
# 240: 0.0332
# 326: 0.0332
# 3500: 0.0332
# 41: 0.0332
# 9001: 0.0000
# academia: 0.0000
# academic: 0.0473
# accomplishment: 0.0332
# accreditation: 0.0000
# accredited: 0.0000
# achievement: 0.0332
# achiever: 0.0332
# achieving: 0.0332
# acm: 0.0332
# actively: 0.0000
# activity: 0.0709
# acumen: 0.0332
# adapting: 0.0332
# additionally: 0.0332
# affiliated: 0.0236
# after: 0.0236
# agency: 0.0000
# ahead: 0.0236
# aicte: 0.0332
# almost: 0.0664
# along: 0.0236
# alongside: 0.0332
# also: 0.1182
# ambassadors: 0.0332
# ambition: 0.0236
# among: 0.0473
# annual: 0.0332
# appreciate: 0.0332
# aptitude: 0.0000
# art: 0.0473
# aspiring: 0.0000
# assessment: 0.0000
# assure: 0.0332
# atmosphere: 0.0000
# attitude: 0.0236
# automobile: 0.0332
# avenue: 0.0000
# average: 0.0332
# award: 0.0332
# bagged: 0.0332
# based: 0.0236
# become: 0.0332
# ...

# %%
print("\nTF-IDF Representation for document 2:")
for word,score in zip(feature_names,tfidf_array[1]):
    print(f"{word}: {score: .4f}")
# Out:
# TF-IDF Representation for document 2:
# 10:  0.0000
# 100:  0.0000
# 12:  0.0000
# 19:  0.0000
# 1983:  0.0316
# 1st:  0.0000
# 2015:  0.0444
# 240:  0.0000
# 326:  0.0000
# 3500:  0.0000
# 41:  0.0000
# 9001:  0.0444
# academia:  0.0444
# academic:  0.0632
# accomplishment:  0.0000
# accreditation:  0.0888
# accredited:  0.0888
# achievement:  0.0000
# achiever:  0.0000
# achieving:  0.0000
# acm:  0.0000
# actively:  0.0444
# activity:  0.0316
# acumen:  0.0000
# adapting:  0.0000
# additionally:  0.0000
# affiliated:  0.0316
# after:  0.0316
# agency:  0.0444
# ahead:  0.0316
# aicte:  0.0000
# almost:  0.0000
# along:  0.0316
# alongside:  0.0000
# also:  0.0632
# ambassadors:  0.0000
# ambition:  0.0316
# among:  0.0316
# annual:  0.0000
# appreciate:  0.0000
# aptitude:  0.0444
# art:  0.0316
# aspiring:  0.0444
# assessment:  0.0444
# assure:  0.0000
# atmosphere:  0.0444
# attitude:  0.0316
# automobile:  0.0000
# avenue:  0.0444
# average:  0.0000
# award:  0.0000
# ...

# %% [markdown]
# TF-IDF Calculation

# %%
import pandas as pd
import math
import numpy as np

# %%
first= processed_texts[0]
second= processed_texts[1]
#split so each word have their own string
first = first.split(" ")
second= second.split(" ")
#print(first,second)
total= set(first).union(set(second))
#print(total)
wordDictA = dict.fromkeys(total, 0)
wordDictB = dict.fromkeys(total, 0)
for word in first:
    wordDictA[word]+=1

for word in second:
    wordDictB[word]+=1
#put them in a dataframe and then view the result:
pd.DataFrame([wordDictA, wordDictB])
# Out:
#    together  Wireless  house  national  Maharashtra  10/10  achievement  \
# 0         1         1      1         1            0      1            1
# 1         0         0      0         0            2      0            0
#
#    Ambassadors/Partners  Concepts  thus  ...  sought-after  Welcome  entire  \
# 0                     1         0     0  ...             1        0       1
# 1                     0         1     1  ...             1        1       2
#
#    medal  consistently  competition  chosen  potential  Cell  society
# 0      1             0            1       1          1     2        2
# 1      0             1            0       0          0     2        0
#
# [2 rows x 552 columns]

# %%
def computeTF(wordDict, bow):
    tfDict = {}
    bowCount = len(bow)
    for word, count in wordDict.items():
        tfDict[word] = count/bowCount
    return tfDict
#running our sentences through the tf function:
tfFirst = computeTF(wordDictA, first)
tfSecond = computeTF(wordDictB, second)
#Converting to dataframe for visualization
tf_df= pd.DataFrame([tfFirst, tfSecond])
tf_df.head()
# Out:
#    together  Wireless     house  national  Maharashtra     10/10  achievement  \
# 0  0.001984  0.001984  0.001984  0.001984     0.000000  0.001984     0.001984
# 1  0.000000  0.000000  0.000000  0.000000     0.005814  0.000000     0.000000
#
#    Ambassadors/Partners  Concepts      thus  ...  sought-after   Welcome  \
# 0              0.001984  0.000000  0.000000  ...      0.001984  0.000000
# 1              0.000000  0.002907  0.002907  ...      0.002907  0.002907
#
#      entire     medal  consistently  competition    chosen  potential  \
# 0  0.001984  0.001984      0.000000     0.001984  0.001984   0.001984
# 1  0.005814  0.000000      0.002907     0.000000  0.000000   0.000000
#
#        Cell   society
# 0  0.003968  0.003968
# 1  0.005814  0.000000
#
# [2 rows x 552 columns]

# %%
def computeIDF(docList):
    idfDict = {}
    N = len(docList)

    idfDict = dict.fromkeys(docList[0].keys(), 0)
    for doc in docList:
        for word, val in doc.items():
            if val > 0:
                idfDict[word] += 1

    for word, val in idfDict.items():
        idfDict[word] = math.log10(N / val)

    return idfDict
#inputing our sentences in the log file
idfs = computeIDF([wordDictA, wordDictB])

# %%
idfs
# Out:
# {'together': 0.3010299956639812,
#  'Wireless': 0.3010299956639812,
#  'house': 0.3010299956639812,
#  'national': 0.3010299956639812,
#  'Maharashtra': 0.3010299956639812,
#  '10/10': 0.3010299956639812,
#  'achievement': 0.3010299956639812,
#  'Ambassadors/Partners': 0.3010299956639812,
#  'Concepts': 0.3010299956639812,
#  'thus': 0.3010299956639812,
#  'going': 0.3010299956639812,
#  'department': 0.3010299956639812,
#  'moulding': 0.3010299956639812,
#  'Education': 0.0,
#  'effort': 0.3010299956639812,
#  'strives': 0.3010299956639812,
#  'learning': 0.0,
#  'securing': 0.3010299956639812,
#  'excellent': 0.0,
#  'special': 0.3010299956639812,
#  'infrastructure': 0.3010299956639812,
#  'critical': 0.3010299956639812,
#  'reputed': 0.3010299956639812,
#  'Racing': 0.3010299956639812,
#  'adapting': 0.3010299956639812,
#  'Dr.': 0.3010299956639812,
#  'throughout': 0.3010299956639812,
#  'Secretary': 0.3010299956639812,
#  'niche': 0.3010299956639812,
# ...

# %%
def computeTFIDF(tfBow, idfs):
    tfidf = {}
    for word, val in tfBow.items():
        tfidf[word] = val*idfs[word]
    return tfidf
#running our two sentences through the IDF:
idfFirst = computeTFIDF(tfFirst, idfs)
idfSecond = computeTFIDF(tfSecond, idfs)
#putting it in a dataframe
idf= pd.DataFrame([idfFirst, idfSecond])

# %%
idf
# Out:
#    together  Wireless     house  national  Maharashtra     10/10  achievement  \
# 0  0.000597  0.000597  0.000597  0.000597      0.00000  0.000597     0.000597
# 1  0.000000  0.000000  0.000000  0.000000      0.00175  0.000000     0.000000
#
#    Ambassadors/Partners  Concepts      thus  ...  sought-after   Welcome  \
# 0              0.000597  0.000000  0.000000  ...           0.0  0.000000
# 1              0.000000  0.000875  0.000875  ...           0.0  0.000875
#
#    entire     medal  consistently  competition    chosen  potential  Cell  \
# 0     0.0  0.000597      0.000000     0.000597  0.000597   0.000597   0.0
# 1     0.0  0.000000      0.000875     0.000000  0.000000   0.000000   0.0
#
#     society
# 0  0.001195
# 1  0.000000
#
# [2 rows x 552 columns]

# %%
# Manual TF-IDF Calculation
N = len(processed_texts)  # Total number of documents
term_freq = []
idf = {}

# Compute Term Frequency (TF)
for text in processed_texts:
    words = text.split()
    total_terms = len(words)
    tf_dict = {word: words.count(word) / total_terms for word in words}
    term_freq.append(tf_dict)

# Compute Document Frequency (DF)
df_counts = {}
for tf_dict in term_freq:
    for word in tf_dict.keys():
        df_counts[word] = df_counts.get(word, 0) + 1

# Compute Inverse Document Frequency (IDF)
for word, df in df_counts.items():
    idf[word] = np.log(N / (1 + df)) + 1

# Compute TF-IDF manually
tf_idf_manual = []
for tf_dict in term_freq:
    tfidf_dict = {word: tf_dict[word] * idf[word] for word in tf_dict.keys()}
    tf_idf_manual.append(tfidf_dict)

# Convert to DataFrame
manual_tfidf_df = pd.DataFrame(tf_idf_manual).fillna(0)
print("Manual TF-IDF Calculation:")
print(manual_tfidf_df)
# Out:
# Manual TF-IDF Calculation:
#       ﻿Pune  Institute  Computer  Technology      PICT  established      1983  \
# 0  0.001984   0.002359  0.005898    0.005898  0.016515     0.001180  0.001180
# 1  0.000000   0.003457  0.005185    0.003457  0.022468     0.001728  0.001728
#
#       group  enterprising  visionary  ...     going  lifetime  experience  \
# 0  0.002359      0.003968   0.001180  ...  0.000000  0.000000    0.000000
# 1  0.003457      0.000000   0.001728  ...  0.002907  0.002907    0.002907
#
#        time      hard     smart   Welcome     buddy    leader   success
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.002907  0.002907  0.002907  0.002907  0.002907  0.002907  0.002907
#
# [2 rows x 552 columns]
